# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/xception-mini-check-data/y_train.npy
# /kaggle/input/xception-mini-check-data/y_test.npy
# /kaggle/input/xception-mini-check-data/y.npy
# /kaggle/input/xception-mini-check-data/X_test.npy
# /kaggle/input/xception-mini-check-data/X_train.npy
# /kaggle/input/xception-mini-check-data/fer2013.csv
# /kaggle/input/xception-mini-check-data/X.npy

# %%
local_path = '../FERData/Std/' # Removed from Github but can generate locally

# %%
# !pip install dlib
# !pip install imutils
# Out:
# Collecting dlib
#   Downloading dlib-19.24.2.tar.gz (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 78.5 MB/s eta 0:00:0000:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml) ... /^C
# anceled
# ERROR: Operation cancelled by user
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25837 sha256=3b925e17f1703480023c8bc97f2484409b58ebc0cbc21987e786c49fef7820e7
#   Stored in directory: /root/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from time import sleep
import re
import os
import argparse
from collections import OrderedDict
import matplotlib.animation as animation

### Image processing ###
from scipy.ndimage import zoom
from scipy.spatial import distance
#import imutils
from scipy import ndimage
import cv2
#import dlib
from __future__ import division
from imutils import face_utils

### CNN models ###
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, SeparableConv2D
#from keras.utils import np_utils
from keras.regularizers import l2#, activity_l2
from keras.optimizers import SGD, RMSprop
from keras.utils import to_categorical
from keras.layers import BatchNormalization
from keras import models
from keras.utils import plot_model
from keras.layers import Input, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras import layers

### Build SVM models ###
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

### Same trained models ###
import h5py
from keras.models import model_from_json
import pickle
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
X_train = np.load(local_path + "X_train.npy")
X_test = np.load(local_path + "X_test.npy")
y_train = np.load(local_path + "y_train.npy")
y_test = np.load(local_path + "y_test.npy")

# %%
#parameters 

batch_size = 128
epochs = 150
shape_x = 48
shape_y = 48
nRows,nCols,nDims = X_train.shape[1:]
input_shape = (nRows, nCols, nDims)
classes = np.unique(y_train)
verbose = True 
num_class = len(classes)
patience = 50  # number of epochs with no improvement after which training will be stopped
base_path = './'
l2_regularization = 0.01
data_generator = ImageDataGenerator(featurewise_center=False, featurewise_std_normalization=False, rotation_range=10, 
                                    width_shift_range=0.1, height_shift_range=0.1, zoom_range=.1, horizontal_flip=True)
regularization = l2(l2_regularization)

# %%
# model
image_input = Input(input_shape)
x = Conv2D(filters=8, kernel_size=(3,3), strides=(1,1), kernel_regularizer=regularization, use_bias=False)(image_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(filters=8, kernel_size=(3,3), strides=(1,1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# module 1
# residual module 
residual = Conv2D(filters=16, kernel_size=(1,1), strides=(2,2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)

x = SeparableConv2D(filters=16, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(filters=16, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
x = layers.add([x,residual])

# module 2
# residual module 
residual = Conv2D(filters=32, kernel_size=(1,1), strides=(2,2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)

x = SeparableConv2D(filters=32, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(filters=32, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
x = layers.add([x,residual])

# module 3
# residual module 
residual = Conv2D(filters=64, kernel_size=(1,1), strides=(2,2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)

x = SeparableConv2D(filters=64, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(filters=64, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
x = layers.add([x,residual])

# module 4
# residual module 
residual = Conv2D(filters=128, kernel_size=(1,1), strides=(2,2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)

x = SeparableConv2D(filters=128, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(filters=128, kernel_size=(3,3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same')(x)
x = layers.add([x,residual])

x = Conv2D(filters=num_class, kernel_size=(3,3), padding='same')(x)
x = GlobalAveragePooling2D()(x)

output = Activation('softmax', name='predictions')(x)

# %%
mini_x_model = Model(image_input, output)
mini_x_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
mini_x_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d_35 (Conv2D)          (None, 46, 46, 8)            72        ['input_6[0][0]']
#
#  batch_normalization_70 (Ba  (None, 46, 46, 8)            32        ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 46, 46, 8)            0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 44, 44, 8)            576       ['activation_30[0][0]']
#
#  batch_normalization_71 (Ba  (None, 44, 44, 8)            32        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 44, 44, 8)            0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  separable_conv2d_40 (Separ  (None, 44, 44, 16)           200       ['activation_31[0][0]']
#  ableConv2D)
#
#  batch_normalization_73 (Ba  (None, 44, 44, 16)           64        ['separable_conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 44, 44, 16)           0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  separable_conv2d_41 (Separ  (None, 44, 44, 16)           400       ['activation_32[0][0]']
#  ableConv2D)
#
#  batch_normalization_74 (Ba  (None, 44, 44, 16)           64        ['separable_conv2d_41[0][0]']
#  tchNormalization)
#
#  conv2d_37 (Conv2D)          (None, 22, 22, 16)           128       ['activation_31[0][0]']
#
#  max_pooling2d_20 (MaxPooli  (None, 22, 22, 16)           0         ['batch_normalization_74[0][0]
#  ng2D)                                                              ']
#
#  batch_normalization_72 (Ba  (None, 22, 22, 16)           64        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 22, 22, 16)           0         ['max_pooling2d_20[0][0]',
#                                                                      'batch_normalization_72[0][0]
#                                                                     ']
#
#  separable_conv2d_42 (Separ  (None, 22, 22, 32)           656       ['add_20[0][0]']
#  ableConv2D)
#
#  batch_normalization_76 (Ba  (None, 22, 22, 32)           128       ['separable_conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 22, 22, 32)           0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  separable_conv2d_43 (Separ  (None, 22, 22, 32)           1312      ['activation_33[0][0]']
#  ableConv2D)
#
#  batch_normalization_77 (Ba  (None, 22, 22, 32)           128       ['separable_conv2d_43[0][0]']
#  tchNormalization)
#
#  conv2d_38 (Conv2D)          (None, 11, 11, 32)           512       ['add_20[0][0]']
#
#  max_pooling2d_21 (MaxPooli  (None, 11, 11, 32)           0         ['batch_normalization_77[0][0]
#  ng2D)                                                              ']
#
#  batch_normalization_75 (Ba  (None, 11, 11, 32)           128       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 11, 11, 32)           0         ['max_pooling2d_21[0][0]',
#                                                                      'batch_normalization_75[0][0]
#                                                                     ']
#
#  separable_conv2d_44 (Separ  (None, 11, 11, 64)           2336      ['add_21[0][0]']
#  ableConv2D)
#
#  batch_normalization_79 (Ba  (None, 11, 11, 64)           256       ['separable_conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 11, 11, 64)           0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  separable_conv2d_45 (Separ  (None, 11, 11, 64)           4672      ['activation_34[0][0]']
#  ableConv2D)
#
#  batch_normalization_80 (Ba  (None, 11, 11, 64)           256       ['separable_conv2d_45[0][0]']
#  tchNormalization)
#
#  conv2d_39 (Conv2D)          (None, 6, 6, 64)             2048      ['add_21[0][0]']
#
#  max_pooling2d_22 (MaxPooli  (None, 6, 6, 64)             0         ['batch_normalization_80[0][0]
#  ng2D)                                                              ']
#
#  batch_normalization_78 (Ba  (None, 6, 6, 64)             256       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 6, 6, 64)             0         ['max_pooling2d_22[0][0]',
#                                                                      'batch_normalization_78[0][0]
#                                                                     ']
#
#  separable_conv2d_46 (Separ  (None, 6, 6, 128)            8768      ['add_22[0][0]']
#  ableConv2D)
#
#  batch_normalization_82 (Ba  (None, 6, 6, 128)            512       ['separable_conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 6, 6, 128)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  separable_conv2d_47 (Separ  (None, 6, 6, 128)            17536     ['activation_35[0][0]']
#  ableConv2D)
#
#  batch_normalization_83 (Ba  (None, 6, 6, 128)            512       ['separable_conv2d_47[0][0]']
#  tchNormalization)
#
#  conv2d_40 (Conv2D)          (None, 3, 3, 128)            8192      ['add_22[0][0]']
#
#  max_pooling2d_23 (MaxPooli  (None, 3, 3, 128)            0         ['batch_normalization_83[0][0]
#  ng2D)                                                              ']
#
#  batch_normalization_81 (Ba  (None, 3, 3, 128)            512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 3, 3, 128)            0         ['max_pooling2d_23[0][0]',
#                                                                      'batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 3, 3, 7)              8071      ['add_23[0][0]']
#
#  global_average_pooling2d_5  (None, 7)                    0         ['conv2d_41[0][0]']
#   (GlobalAveragePooling2D)
#
#  predictions (Activation)    (None, 7)                    0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 58423 (228.21 KB)
# Trainable params: 56951 (222.46 KB)
# Non-trainable params: 1472 (5.75 KB)
# __________________________________________________________________________________________________

# %%
plot_model(mini_x_model, to_file='mini_x_model.png', show_shapes=True, show_layer_names=True)

# %%
# callbacks 
early_stop = EarlyStopping(monitor='val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=int(patience/4), verbose=verbose)

trained_models_path = base_path + '_mini_xception'
model_names = trained_models_path + 'model.hdf5'
model_checkpoint = ModelCheckpoint(filepath=model_names, monitor='val_loss', verbose=verbose, save_best_only=True)

callbacks = [model_checkpoint,  early_stop, reduce_lr]

# %%
train_labels_one_hot = to_categorical(y_train)
test_labels_one_hot = to_categorical(y_test)

# %%
history=mini_x_model.fit(data_generator.flow(X_train, train_labels_one_hot, batch_size), 
                  steps_per_epoch=int(np.ceil(X_train.shape[0] / float(batch_size))), epochs=epochs, verbose=verbose, 
                    callbacks=callbacks, validation_data=(X_test, test_labels_one_hot))
# Out:
# Epoch 1/150
# 225/225 [==============================] - ETA: 0s - loss: 1.4520 - accuracy: 0.4637
# Epoch 1: val_loss improved from inf to 1.59130, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.4520 - accuracy: 0.4637 - val_loss: 1.5913 - val_accuracy: 0.4196 - lr: 0.0010
# Epoch 2/150
# 224/225 [============================>.] - ETA: 0s - loss: 1.3926 - accuracy: 0.4844
# Epoch 2: val_loss improved from 1.59130 to 1.49443, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 56ms/step - loss: 1.3924 - accuracy: 0.4847 - val_loss: 1.4944 - val_accuracy: 0.4394 - lr: 0.0010
# Epoch 3/150
# 225/225 [==============================] - ETA: 0s - loss: 1.3502 - accuracy: 0.4968
# Epoch 3: val_loss did not improve from 1.49443
# 225/225 [==============================] - 13s 56ms/step - loss: 1.3502 - accuracy: 0.4968 - val_loss: 1.7161 - val_accuracy: 0.3884 - lr: 0.0010
# Epoch 4/150
# 225/225 [==============================] - ETA: 0s - loss: 1.2960 - accuracy: 0.5183
# Epoch 4: val_loss improved from 1.49443 to 1.37711, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 58ms/step - loss: 1.2960 - accuracy: 0.5183 - val_loss: 1.3771 - val_accuracy: 0.4976 - lr: 0.0010
# Epoch 5/150
# 224/225 [============================>.] - ETA: 0s - loss: 1.2665 - accuracy: 0.5299
# Epoch 5: val_loss improved from 1.37711 to 1.33661, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 59ms/step - loss: 1.2665 - accuracy: 0.5298 - val_loss: 1.3366 - val_accuracy: 0.4996 - lr: 0.0010
# Epoch 6/150
# 225/225 [==============================] - ETA: 0s - loss: 1.2416 - accuracy: 0.5378
# Epoch 6: val_loss improved from 1.33661 to 1.31273, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.2416 - accuracy: 0.5378 - val_loss: 1.3127 - val_accuracy: 0.5138 - lr: 0.0010
# Epoch 7/150
# 225/225 [==============================] - ETA: 0s - loss: 1.2236 - accuracy: 0.5458
# Epoch 7: val_loss did not improve from 1.31273
# 225/225 [==============================] - 13s 57ms/step - loss: 1.2236 - accuracy: 0.5458 - val_loss: 1.3482 - val_accuracy: 0.5102 - lr: 0.0010
# Epoch 8/150
# 225/225 [==============================] - ETA: 0s - loss: 1.2064 - accuracy: 0.5507
# Epoch 8: val_loss improved from 1.31273 to 1.29464, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.2064 - accuracy: 0.5507 - val_loss: 1.2946 - val_accuracy: 0.5191 - lr: 0.0010
# Epoch 9/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1797 - accuracy: 0.5621
# Epoch 9: val_loss did not improve from 1.29464
# 225/225 [==============================] - 13s 57ms/step - loss: 1.1797 - accuracy: 0.5621 - val_loss: 1.3118 - val_accuracy: 0.5194 - lr: 0.0010
# Epoch 10/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1709 - accuracy: 0.5643
# Epoch 10: val_loss improved from 1.29464 to 1.28541, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.1709 - accuracy: 0.5643 - val_loss: 1.2854 - val_accuracy: 0.5344 - lr: 0.0010
# Epoch 11/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1526 - accuracy: 0.5694
# Epoch 11: val_loss did not improve from 1.28541
# 225/225 [==============================] - 13s 56ms/step - loss: 1.1526 - accuracy: 0.5694 - val_loss: 1.3719 - val_accuracy: 0.5130 - lr: 0.0010
# Epoch 12/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.5770
# Epoch 12: val_loss did not improve from 1.28541
# 225/225 [==============================] - 13s 56ms/step - loss: 1.1384 - accuracy: 0.5770 - val_loss: 1.3452 - val_accuracy: 0.5216 - lr: 0.0010
# Epoch 13/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1332 - accuracy: 0.5747
# Epoch 13: val_loss did not improve from 1.28541
# 225/225 [==============================] - 13s 56ms/step - loss: 1.1332 - accuracy: 0.5747 - val_loss: 1.5300 - val_accuracy: 0.4971 - lr: 0.0010
# Epoch 14/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1210 - accuracy: 0.5822
# Epoch 14: val_loss improved from 1.28541 to 1.14832, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.1210 - accuracy: 0.5822 - val_loss: 1.1483 - val_accuracy: 0.5815 - lr: 0.0010
# Epoch 15/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1138 - accuracy: 0.5820
# Epoch 15: val_loss did not improve from 1.14832
# 225/225 [==============================] - 13s 58ms/step - loss: 1.1138 - accuracy: 0.5820 - val_loss: 1.1992 - val_accuracy: 0.5623 - lr: 0.0010
# Epoch 16/150
# 225/225 [==============================] - ETA: 0s - loss: 1.1009 - accuracy: 0.5892
# Epoch 16: val_loss did not improve from 1.14832
# 225/225 [==============================] - 13s 56ms/step - loss: 1.1009 - accuracy: 0.5892 - val_loss: 1.2939 - val_accuracy: 0.5291 - lr: 0.0010
# Epoch 17/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0942 - accuracy: 0.5936
# Epoch 17: val_loss improved from 1.14832 to 1.13023, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 1.0942 - accuracy: 0.5936 - val_loss: 1.1302 - val_accuracy: 0.5815 - lr: 0.0010
# Epoch 18/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.5939
# Epoch 18: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0828 - accuracy: 0.5939 - val_loss: 1.2039 - val_accuracy: 0.5651 - lr: 0.0010
# Epoch 19/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0813 - accuracy: 0.5979
# Epoch 19: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0813 - accuracy: 0.5979 - val_loss: 1.1993 - val_accuracy: 0.5581 - lr: 0.0010
# Epoch 20/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0671 - accuracy: 0.6036
# Epoch 20: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 58ms/step - loss: 1.0671 - accuracy: 0.6036 - val_loss: 1.2083 - val_accuracy: 0.5639 - lr: 0.0010
# Epoch 21/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0604 - accuracy: 0.6054
# Epoch 21: val_loss did not improve from 1.13023
# 225/225 [==============================] - 12s 55ms/step - loss: 1.0604 - accuracy: 0.6054 - val_loss: 1.2711 - val_accuracy: 0.5603 - lr: 0.0010
# Epoch 22/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0524 - accuracy: 0.6054
# Epoch 22: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 58ms/step - loss: 1.0524 - accuracy: 0.6054 - val_loss: 1.1978 - val_accuracy: 0.5801 - lr: 0.0010
# Epoch 23/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0526 - accuracy: 0.6088
# Epoch 23: val_loss did not improve from 1.13023
# 225/225 [==============================] - 12s 55ms/step - loss: 1.0526 - accuracy: 0.6088 - val_loss: 1.1772 - val_accuracy: 0.5887 - lr: 0.0010
# Epoch 24/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0461 - accuracy: 0.6093
# Epoch 24: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 59ms/step - loss: 1.0461 - accuracy: 0.6093 - val_loss: 1.1917 - val_accuracy: 0.5712 - lr: 0.0010
# Epoch 25/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0425 - accuracy: 0.6147
# Epoch 25: val_loss did not improve from 1.13023
# 225/225 [==============================] - 13s 58ms/step - loss: 1.0425 - accuracy: 0.6147 - val_loss: 1.2483 - val_accuracy: 0.5469 - lr: 0.0010
# Epoch 26/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0283 - accuracy: 0.6196
# Epoch 26: val_loss improved from 1.13023 to 1.10234, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0283 - accuracy: 0.6196 - val_loss: 1.1023 - val_accuracy: 0.5979 - lr: 0.0010
# Epoch 27/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0328 - accuracy: 0.6165
# Epoch 27: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0328 - accuracy: 0.6165 - val_loss: 1.1294 - val_accuracy: 0.5901 - lr: 0.0010
# Epoch 28/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0242 - accuracy: 0.6207
# Epoch 28: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0242 - accuracy: 0.6207 - val_loss: 1.1990 - val_accuracy: 0.5681 - lr: 0.0010
# Epoch 29/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0184 - accuracy: 0.6207
# Epoch 29: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0184 - accuracy: 0.6207 - val_loss: 1.1029 - val_accuracy: 0.6007 - lr: 0.0010
# Epoch 30/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0188 - accuracy: 0.6203
# Epoch 30: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0188 - accuracy: 0.6203 - val_loss: 1.2112 - val_accuracy: 0.5720 - lr: 0.0010
# Epoch 31/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0096 - accuracy: 0.6252
# Epoch 31: val_loss did not improve from 1.10234
# 225/225 [==============================] - 12s 55ms/step - loss: 1.0096 - accuracy: 0.6252 - val_loss: 1.1733 - val_accuracy: 0.5756 - lr: 0.0010
# Epoch 32/150
# 225/225 [==============================] - ETA: 0s - loss: 1.0061 - accuracy: 0.6240
# Epoch 32: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 57ms/step - loss: 1.0061 - accuracy: 0.6240 - val_loss: 1.2188 - val_accuracy: 0.5617 - lr: 0.0010
# Epoch 33/150
# 224/225 [============================>.] - ETA: 0s - loss: 1.0037 - accuracy: 0.6287
# Epoch 33: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0039 - accuracy: 0.6286 - val_loss: 1.1486 - val_accuracy: 0.5921 - lr: 0.0010
# Epoch 34/150
# 224/225 [============================>.] - ETA: 0s - loss: 1.0039 - accuracy: 0.6265
# Epoch 34: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 1.0034 - accuracy: 0.6266 - val_loss: 1.1040 - val_accuracy: 0.5832 - lr: 0.0010
# Epoch 35/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.9945 - accuracy: 0.6334
# Epoch 35: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9945 - accuracy: 0.6335 - val_loss: 1.1413 - val_accuracy: 0.5832 - lr: 0.0010
# Epoch 36/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9961 - accuracy: 0.6283
# Epoch 36: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9961 - accuracy: 0.6283 - val_loss: 1.1411 - val_accuracy: 0.5874 - lr: 0.0010
# Epoch 37/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9841 - accuracy: 0.6350
# Epoch 37: val_loss did not improve from 1.10234
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9841 - accuracy: 0.6350 - val_loss: 1.1324 - val_accuracy: 0.5935 - lr: 0.0010
# Epoch 38/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9848 - accuracy: 0.6349
# Epoch 38: val_loss did not improve from 1.10234
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9848 - accuracy: 0.6349 - val_loss: 1.1758 - val_accuracy: 0.5834 - lr: 0.0010
# Epoch 39/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9419 - accuracy: 0.6494
# Epoch 39: val_loss improved from 1.10234 to 1.04246, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9419 - accuracy: 0.6494 - val_loss: 1.0425 - val_accuracy: 0.6211 - lr: 1.0000e-04
# Epoch 40/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9290 - accuracy: 0.6546
# Epoch 40: val_loss did not improve from 1.04246
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9290 - accuracy: 0.6546 - val_loss: 1.0580 - val_accuracy: 0.6191 - lr: 1.0000e-04
# Epoch 41/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9232 - accuracy: 0.6566
# Epoch 41: val_loss improved from 1.04246 to 1.04139, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9232 - accuracy: 0.6566 - val_loss: 1.0414 - val_accuracy: 0.6222 - lr: 1.0000e-04
# Epoch 42/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9146 - accuracy: 0.6605
# Epoch 42: val_loss improved from 1.04139 to 1.03843, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9146 - accuracy: 0.6605 - val_loss: 1.0384 - val_accuracy: 0.6269 - lr: 1.0000e-04
# Epoch 43/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9176 - accuracy: 0.6591
# Epoch 43: val_loss did not improve from 1.03843
# 225/225 [==============================] - 12s 55ms/step - loss: 0.9176 - accuracy: 0.6591 - val_loss: 1.0420 - val_accuracy: 0.6219 - lr: 1.0000e-04
# Epoch 44/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9167 - accuracy: 0.6596
# Epoch 44: val_loss did not improve from 1.03843
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9167 - accuracy: 0.6596 - val_loss: 1.0395 - val_accuracy: 0.6252 - lr: 1.0000e-04
# Epoch 45/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9151 - accuracy: 0.6606
# Epoch 45: val_loss improved from 1.03843 to 1.03695, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 58ms/step - loss: 0.9151 - accuracy: 0.6606 - val_loss: 1.0370 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 46/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9120 - accuracy: 0.6623
# Epoch 46: val_loss did not improve from 1.03695
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9120 - accuracy: 0.6623 - val_loss: 1.0404 - val_accuracy: 0.6328 - lr: 1.0000e-04
# Epoch 47/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9085 - accuracy: 0.6653
# Epoch 47: val_loss did not improve from 1.03695
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9085 - accuracy: 0.6653 - val_loss: 1.0427 - val_accuracy: 0.6275 - lr: 1.0000e-04
# Epoch 48/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9046 - accuracy: 0.6639
# Epoch 48: val_loss did not improve from 1.03695
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9046 - accuracy: 0.6639 - val_loss: 1.0554 - val_accuracy: 0.6213 - lr: 1.0000e-04
# Epoch 49/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9066 - accuracy: 0.6650
# Epoch 49: val_loss did not improve from 1.03695
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9066 - accuracy: 0.6650 - val_loss: 1.0371 - val_accuracy: 0.6247 - lr: 1.0000e-04
# Epoch 50/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9051 - accuracy: 0.6639
# Epoch 50: val_loss did not improve from 1.03695
# 225/225 [==============================] - 12s 55ms/step - loss: 0.9051 - accuracy: 0.6639 - val_loss: 1.0421 - val_accuracy: 0.6227 - lr: 1.0000e-04
# Epoch 51/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.9087 - accuracy: 0.6623
# Epoch 51: val_loss improved from 1.03695 to 1.03393, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9088 - accuracy: 0.6623 - val_loss: 1.0339 - val_accuracy: 0.6239 - lr: 1.0000e-04
# Epoch 52/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9016 - accuracy: 0.6679
# Epoch 52: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 57ms/step - loss: 0.9016 - accuracy: 0.6679 - val_loss: 1.0352 - val_accuracy: 0.6241 - lr: 1.0000e-04
# Epoch 53/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9034 - accuracy: 0.6644
# Epoch 53: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9034 - accuracy: 0.6644 - val_loss: 1.0354 - val_accuracy: 0.6247 - lr: 1.0000e-04
# Epoch 54/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9023 - accuracy: 0.6669
# Epoch 54: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9023 - accuracy: 0.6669 - val_loss: 1.0565 - val_accuracy: 0.6227 - lr: 1.0000e-04
# Epoch 55/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.6669
# Epoch 55: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8939 - accuracy: 0.6669 - val_loss: 1.0346 - val_accuracy: 0.6300 - lr: 1.0000e-04
# Epoch 56/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9019 - accuracy: 0.6676
# Epoch 56: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9019 - accuracy: 0.6676 - val_loss: 1.0412 - val_accuracy: 0.6294 - lr: 1.0000e-04
# Epoch 57/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8955 - accuracy: 0.6703
# Epoch 57: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8955 - accuracy: 0.6703 - val_loss: 1.0393 - val_accuracy: 0.6258 - lr: 1.0000e-04
# Epoch 58/150
# 225/225 [==============================] - ETA: 0s - loss: 0.9026 - accuracy: 0.6648
# Epoch 58: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.9026 - accuracy: 0.6648 - val_loss: 1.0439 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 59/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8984 - accuracy: 0.6655
# Epoch 59: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8984 - accuracy: 0.6655 - val_loss: 1.0394 - val_accuracy: 0.6311 - lr: 1.0000e-04
# Epoch 60/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8965 - accuracy: 0.6690
# Epoch 60: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8965 - accuracy: 0.6690 - val_loss: 1.0373 - val_accuracy: 0.6258 - lr: 1.0000e-04
# Epoch 61/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.6689
# Epoch 61: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8925 - accuracy: 0.6689 - val_loss: 1.0362 - val_accuracy: 0.6297 - lr: 1.0000e-04
# Epoch 62/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8874 - accuracy: 0.6732
# Epoch 62: val_loss did not improve from 1.03393
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8874 - accuracy: 0.6732 - val_loss: 1.0353 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Epoch 63/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8876 - accuracy: 0.6720
# Epoch 63: val_loss did not improve from 1.03393
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8876 - accuracy: 0.6720 - val_loss: 1.0371 - val_accuracy: 0.6216 - lr: 1.0000e-04
# Epoch 64/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8880 - accuracy: 0.6708
# Epoch 64: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8880 - accuracy: 0.6708 - val_loss: 1.0364 - val_accuracy: 0.6244 - lr: 1.0000e-05
# Epoch 65/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8881 - accuracy: 0.6666
# Epoch 65: val_loss did not improve from 1.03393
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8881 - accuracy: 0.6666 - val_loss: 1.0345 - val_accuracy: 0.6239 - lr: 1.0000e-05
# Epoch 66/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8891 - accuracy: 0.6726
# Epoch 66: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8891 - accuracy: 0.6726 - val_loss: 1.0348 - val_accuracy: 0.6233 - lr: 1.0000e-05
# Epoch 67/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8836 - accuracy: 0.6735
# Epoch 67: val_loss did not improve from 1.03393
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8836 - accuracy: 0.6735 - val_loss: 1.0362 - val_accuracy: 0.6239 - lr: 1.0000e-05
# Epoch 68/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8808 - accuracy: 0.6733
# Epoch 68: val_loss did not improve from 1.03393
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8808 - accuracy: 0.6733 - val_loss: 1.0344 - val_accuracy: 0.6241 - lr: 1.0000e-05
# Epoch 69/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8831 - accuracy: 0.6731
# Epoch 69: val_loss did not improve from 1.03393
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8831 - accuracy: 0.6731 - val_loss: 1.0352 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 70/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8896 - accuracy: 0.6698
# Epoch 70: val_loss improved from 1.03393 to 1.03319, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8896 - accuracy: 0.6698 - val_loss: 1.0332 - val_accuracy: 0.6255 - lr: 1.0000e-05
# Epoch 71/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8852 - accuracy: 0.6715
# Epoch 71: val_loss did not improve from 1.03319
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8852 - accuracy: 0.6715 - val_loss: 1.0354 - val_accuracy: 0.6255 - lr: 1.0000e-05
# Epoch 72/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8831 - accuracy: 0.6713
# Epoch 72: val_loss did not improve from 1.03319
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8831 - accuracy: 0.6713 - val_loss: 1.0340 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 73/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.6743
# Epoch 73: val_loss improved from 1.03319 to 1.03116, saving model to ./_mini_xceptionmodel.hdf5
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8824 - accuracy: 0.6743 - val_loss: 1.0312 - val_accuracy: 0.6258 - lr: 1.0000e-05
# Epoch 74/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8836 - accuracy: 0.6719
# Epoch 74: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8836 - accuracy: 0.6719 - val_loss: 1.0335 - val_accuracy: 0.6269 - lr: 1.0000e-05
# Epoch 75/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8871 - accuracy: 0.6736
# Epoch 75: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8871 - accuracy: 0.6736 - val_loss: 1.0365 - val_accuracy: 0.6239 - lr: 1.0000e-05
# Epoch 76/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.6744
# Epoch 76: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8811 - accuracy: 0.6744 - val_loss: 1.0329 - val_accuracy: 0.6255 - lr: 1.0000e-05
# Epoch 77/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8870 - accuracy: 0.6709
# Epoch 77: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8870 - accuracy: 0.6709 - val_loss: 1.0344 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 78/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8843 - accuracy: 0.6721
# Epoch 78: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8843 - accuracy: 0.6721 - val_loss: 1.0330 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 79/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8842 - accuracy: 0.6747
# Epoch 79: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8842 - accuracy: 0.6747 - val_loss: 1.0362 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 80/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8852 - accuracy: 0.6737
# Epoch 80: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8852 - accuracy: 0.6737 - val_loss: 1.0314 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 81/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8848 - accuracy: 0.6723
# Epoch 81: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8848 - accuracy: 0.6723 - val_loss: 1.0327 - val_accuracy: 0.6261 - lr: 1.0000e-05
# Epoch 82/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8778 - accuracy: 0.6754
# Epoch 82: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8778 - accuracy: 0.6754 - val_loss: 1.0327 - val_accuracy: 0.6272 - lr: 1.0000e-05
# Epoch 83/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8798 - accuracy: 0.6749
# Epoch 83: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8798 - accuracy: 0.6749 - val_loss: 1.0335 - val_accuracy: 0.6255 - lr: 1.0000e-05
# Epoch 84/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8838 - accuracy: 0.6722
# Epoch 84: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8838 - accuracy: 0.6722 - val_loss: 1.0314 - val_accuracy: 0.6280 - lr: 1.0000e-05
# Epoch 85/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8848 - accuracy: 0.6721
# Epoch 85: val_loss did not improve from 1.03116
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8849 - accuracy: 0.6721 - val_loss: 1.0321 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 86/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8835 - accuracy: 0.6728
# Epoch 86: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8835 - accuracy: 0.6728 - val_loss: 1.0328 - val_accuracy: 0.6252 - lr: 1.0000e-06
# Epoch 87/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8834 - accuracy: 0.6739
# Epoch 87: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8840 - accuracy: 0.6737 - val_loss: 1.0329 - val_accuracy: 0.6261 - lr: 1.0000e-06
# Epoch 88/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8813 - accuracy: 0.6747
# Epoch 88: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8813 - accuracy: 0.6747 - val_loss: 1.0329 - val_accuracy: 0.6258 - lr: 1.0000e-06
# Epoch 89/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8866 - accuracy: 0.6714
# Epoch 89: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8866 - accuracy: 0.6714 - val_loss: 1.0330 - val_accuracy: 0.6261 - lr: 1.0000e-06
# Epoch 90/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8787 - accuracy: 0.6759
# Epoch 90: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8796 - accuracy: 0.6757 - val_loss: 1.0328 - val_accuracy: 0.6272 - lr: 1.0000e-06
# Epoch 91/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8789 - accuracy: 0.6749
# Epoch 91: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8789 - accuracy: 0.6749 - val_loss: 1.0322 - val_accuracy: 0.6280 - lr: 1.0000e-06
# Epoch 92/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8824 - accuracy: 0.6734
# Epoch 92: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8824 - accuracy: 0.6734 - val_loss: 1.0324 - val_accuracy: 0.6272 - lr: 1.0000e-06
# Epoch 93/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8829 - accuracy: 0.6732
# Epoch 93: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8829 - accuracy: 0.6732 - val_loss: 1.0321 - val_accuracy: 0.6275 - lr: 1.0000e-06
# Epoch 94/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8830 - accuracy: 0.6747
# Epoch 94: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8830 - accuracy: 0.6747 - val_loss: 1.0326 - val_accuracy: 0.6266 - lr: 1.0000e-06
# Epoch 95/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8829 - accuracy: 0.6759
# Epoch 95: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 55ms/step - loss: 0.8829 - accuracy: 0.6759 - val_loss: 1.0327 - val_accuracy: 0.6266 - lr: 1.0000e-06
# Epoch 96/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8836 - accuracy: 0.6732
# Epoch 96: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8836 - accuracy: 0.6732 - val_loss: 1.0324 - val_accuracy: 0.6269 - lr: 1.0000e-06
# Epoch 97/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8820 - accuracy: 0.6742
# Epoch 97: val_loss did not improve from 1.03116
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8820 - accuracy: 0.6742 - val_loss: 1.0327 - val_accuracy: 0.6283 - lr: 1.0000e-06
# Epoch 98/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8778 - accuracy: 0.6768
# Epoch 98: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8778 - accuracy: 0.6768 - val_loss: 1.0328 - val_accuracy: 0.6275 - lr: 1.0000e-07
# Epoch 99/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.6760
# Epoch 99: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8806 - accuracy: 0.6760 - val_loss: 1.0328 - val_accuracy: 0.6269 - lr: 1.0000e-07
# Epoch 100/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.6728
# Epoch 100: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8819 - accuracy: 0.6728 - val_loss: 1.0327 - val_accuracy: 0.6269 - lr: 1.0000e-07
# Epoch 101/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8838 - accuracy: 0.6730
# Epoch 101: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8838 - accuracy: 0.6730 - val_loss: 1.0326 - val_accuracy: 0.6272 - lr: 1.0000e-07
# Epoch 102/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8841 - accuracy: 0.6753
# Epoch 102: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8841 - accuracy: 0.6753 - val_loss: 1.0326 - val_accuracy: 0.6266 - lr: 1.0000e-07
# Epoch 103/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8822 - accuracy: 0.6712
# Epoch 103: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8822 - accuracy: 0.6712 - val_loss: 1.0325 - val_accuracy: 0.6275 - lr: 1.0000e-07
# Epoch 104/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8825 - accuracy: 0.6740
# Epoch 104: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 57ms/step - loss: 0.8825 - accuracy: 0.6740 - val_loss: 1.0326 - val_accuracy: 0.6275 - lr: 1.0000e-07
# Epoch 105/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8841 - accuracy: 0.6729
# Epoch 105: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8841 - accuracy: 0.6729 - val_loss: 1.0329 - val_accuracy: 0.6261 - lr: 1.0000e-07
# Epoch 106/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8812 - accuracy: 0.6733
# Epoch 106: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8812 - accuracy: 0.6733 - val_loss: 1.0327 - val_accuracy: 0.6269 - lr: 1.0000e-07
# Epoch 107/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8895 - accuracy: 0.6703
# Epoch 107: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8895 - accuracy: 0.6703 - val_loss: 1.0325 - val_accuracy: 0.6272 - lr: 1.0000e-07
# Epoch 108/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8825 - accuracy: 0.6754
# Epoch 108: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8825 - accuracy: 0.6754 - val_loss: 1.0320 - val_accuracy: 0.6272 - lr: 1.0000e-07
# Epoch 109/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8813 - accuracy: 0.6756
# Epoch 109: val_loss did not improve from 1.03116
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8814 - accuracy: 0.6756 - val_loss: 1.0329 - val_accuracy: 0.6272 - lr: 1.0000e-07
# Epoch 110/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8837 - accuracy: 0.6736
# Epoch 110: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8837 - accuracy: 0.6736 - val_loss: 1.0327 - val_accuracy: 0.6266 - lr: 1.0000e-08
# Epoch 111/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8826 - accuracy: 0.6747
# Epoch 111: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8825 - accuracy: 0.6748 - val_loss: 1.0327 - val_accuracy: 0.6269 - lr: 1.0000e-08
# Epoch 112/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8806 - accuracy: 0.6767
# Epoch 112: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8806 - accuracy: 0.6767 - val_loss: 1.0327 - val_accuracy: 0.6269 - lr: 1.0000e-08
# Epoch 113/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8812 - accuracy: 0.6765
# Epoch 113: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 55ms/step - loss: 0.8814 - accuracy: 0.6764 - val_loss: 1.0328 - val_accuracy: 0.6272 - lr: 1.0000e-08
# Epoch 114/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8834 - accuracy: 0.6753
# Epoch 114: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 55ms/step - loss: 0.8834 - accuracy: 0.6753 - val_loss: 1.0326 - val_accuracy: 0.6272 - lr: 1.0000e-08
# Epoch 115/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8796 - accuracy: 0.6730
# Epoch 115: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 54ms/step - loss: 0.8796 - accuracy: 0.6730 - val_loss: 1.0326 - val_accuracy: 0.6261 - lr: 1.0000e-08
# Epoch 116/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8872 - accuracy: 0.6720
# Epoch 116: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8872 - accuracy: 0.6720 - val_loss: 1.0327 - val_accuracy: 0.6264 - lr: 1.0000e-08
# Epoch 117/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8838 - accuracy: 0.6752
# Epoch 117: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8838 - accuracy: 0.6752 - val_loss: 1.0328 - val_accuracy: 0.6278 - lr: 1.0000e-08
# Epoch 118/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.6798
# Epoch 118: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 54ms/step - loss: 0.8785 - accuracy: 0.6798 - val_loss: 1.0327 - val_accuracy: 0.6272 - lr: 1.0000e-08
# Epoch 119/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8839 - accuracy: 0.6726
# Epoch 119: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8839 - accuracy: 0.6726 - val_loss: 1.0323 - val_accuracy: 0.6275 - lr: 1.0000e-08
# Epoch 120/150
# 224/225 [============================>.] - ETA: 0s - loss: 0.8832 - accuracy: 0.6757
# Epoch 120: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8835 - accuracy: 0.6756 - val_loss: 1.0327 - val_accuracy: 0.6272 - lr: 1.0000e-08
# Epoch 121/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8799 - accuracy: 0.6768
# Epoch 121: val_loss did not improve from 1.03116
#
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8799 - accuracy: 0.6768 - val_loss: 1.0328 - val_accuracy: 0.6275 - lr: 1.0000e-08
# Epoch 122/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8894 - accuracy: 0.6686
# Epoch 122: val_loss did not improve from 1.03116
# 225/225 [==============================] - 13s 56ms/step - loss: 0.8894 - accuracy: 0.6686 - val_loss: 1.0329 - val_accuracy: 0.6269 - lr: 1.0000e-09
# Epoch 123/150
# 225/225 [==============================] - ETA: 0s - loss: 0.8828 - accuracy: 0.6736
# Epoch 123: val_loss did not improve from 1.03116
# 225/225 [==============================] - 12s 55ms/step - loss: 0.8828 - accuracy: 0.6736 - val_loss: 1.0329 - val_accuracy: 0.6266 - lr: 1.0000e-09

# %%
#Plotting accuracy and loss curves for mini_x_model

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=2.0)
plt.plot(history.history['val_loss'],'b',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
plt.savefig('Mini_Xception_loss_trainingStats.png')
 
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
plt.savefig('Mini_Xception_Acc_trainingStats.png')
