# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
local_path = '../FERData/Std/' # Removed from Github but can generate locally

# %%
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25837 sha256=250b54ff3169a4267112a7c3847b7afc35b38ec780f44d6b1863f64116deda2c
#   Stored in directory: /root/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
# !pip install dlib
# Out:
# Collecting dlib
#   Downloading dlib-19.24.2.tar.gz (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 67.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml) ... done
#   Created wheel for dlib: filename=dlib-19.24.2-cp310-cp310-linux_x86_64.whl size=3828866 sha256=9011ea539e60d8c8c3e87012f070a19730ce8b61fd35708a846da8d118986e42
#   Stored in directory: /root/.cache/pip/wheels/9b/e2/80/888fdc098db86b463ff0c83ae5e5ca151889e901bc1e9a3a11
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-19.24.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
from time import sleep
import re
import os
import argparse
from collections import OrderedDict
import matplotlib.animation as animation

### Image processing ###
from scipy.ndimage import zoom
from scipy.spatial import distance
import imutils
from scipy import ndimage
import cv2
import dlib
from __future__ import division
from imutils import face_utils

### CNN models ###
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, SeparableConv2D
#from keras.utils import np_utils
from keras.regularizers import l2#, activity_l2
from keras.optimizers import SGD, RMSprop
from keras.utils import to_categorical
from keras.layers import BatchNormalization
from keras import models
from keras.utils import plot_model
from keras.layers import Input, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras import layers

### Build SVM models ###
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

### Same trained models ###
import h5py
from keras.models import model_from_json
import pickle
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X_train = np.load(local_path + "X_train.npy")
X_test = np.load(local_path + "X_test.npy")
y_train = np.load(local_path + "y_train.npy")
y_test = np.load(local_path + "y_test.npy")

# %%
shape_x = 48
shape_y = 48
nRows,nCols,nDims = X_train.shape[1:]
input_shape = (nRows, nCols, nDims)
classes = np.unique(y_train)
nClasses = len(classes)

# %%
def entry_flow(inputs) :
    
    x = Conv2D(32, 3, strides = 2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(64,3,padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    previous_block_activation = x
    
    for size in [128, 256, 728] :
    
        x = Activation('relu')(x)
        x = SeparableConv2D(size, 3, padding='same')(x)
        x = BatchNormalization()(x)
    
        x = Activation('relu')(x)
        x = SeparableConv2D(size, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = MaxPooling2D(3, strides=2, padding='same')(x)
        
        residual = Conv2D(size, 1, strides=2, padding='same')(previous_block_activation)
        
        x = keras.layers.Add()([x, residual])
        previous_block_activation = x
    
    return x

# %%
def middle_flow(x, num_blocks=8) :
    
    previous_block_activation = x
    
    for _ in range(num_blocks) :
    
        x = Activation('relu')(x)
        x = SeparableConv2D(728, 3, padding='same')(x)
        x = BatchNormalization()(x)
    
        x = Activation('relu')(x)
        x = SeparableConv2D(728, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = Activation('relu')(x)
        x = SeparableConv2D(728, 3, padding='same')(x)
        x = BatchNormalization()(x)
        
        x = keras.layers.Add()([x, previous_block_activation])
        previous_block_activation = x
    
    return x

# %%
def exit_flow(x, num_classes=7) :
    
    previous_block_activation = x
    
    x = Activation('relu')(x)
    x = SeparableConv2D(728, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Activation('relu')(x)
    x = SeparableConv2D(1024, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling2D(3, strides=2, padding='same')(x)
    
    residual = Conv2D(1024, 1, strides=2, padding='same')(previous_block_activation)
    x = keras.layers.Add()([x, residual])
      
    x = Activation('relu')(x)
    x = SeparableConv2D(728, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = Activation('relu')(x)
    x = SeparableConv2D(1024, 3, padding='same')(x)
    x = BatchNormalization()(x)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)
    
    return x

# %%
inputs = Input(shape=(shape_x, shape_y, 1))
outputs = exit_flow(middle_flow(entry_flow(inputs)))

# %%
xception = Model(inputs, outputs)

# %%
plot_model(xception, to_file='Xception.png', show_shapes=True, show_layer_names=True)

# %%
xception.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 48, 48, 7)]          0         []
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 32)           2048      ['input_3[0][0]']
#
#  batch_normalization_36 (Ba  (None, 24, 24, 32)           128       ['conv2d_6[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 24, 24, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)           18496     ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 24, 24, 64)           256       ['conv2d_7[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 24, 24, 64)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 24, 24, 64)           0         ['activation_37[0][0]']
#
#  separable_conv2d_34 (Separ  (None, 24, 24, 128)          8896      ['activation_38[0][0]']
#  ableConv2D)
#
#  batch_normalization_38 (Ba  (None, 24, 24, 128)          512       ['separable_conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 24, 24, 128)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  separable_conv2d_35 (Separ  (None, 24, 24, 128)          17664     ['activation_39[0][0]']
#  ableConv2D)
#
#  batch_normalization_39 (Ba  (None, 24, 24, 128)          512       ['separable_conv2d_35[0][0]']
#  tchNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 12, 12, 128)          0         ['batch_normalization_39[0][0]
#  g2D)                                                               ']
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)          8320      ['activation_37[0][0]']
#
#  add_12 (Add)                (None, 12, 12, 128)          0         ['max_pooling2d_4[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  activation_40 (Activation)  (None, 12, 12, 128)          0         ['add_12[0][0]']
#
#  separable_conv2d_36 (Separ  (None, 12, 12, 256)          34176     ['activation_40[0][0]']
#  ableConv2D)
#
#  batch_normalization_40 (Ba  (None, 12, 12, 256)          1024      ['separable_conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 12, 12, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  separable_conv2d_37 (Separ  (None, 12, 12, 256)          68096     ['activation_41[0][0]']
#  ableConv2D)
#
#  batch_normalization_41 (Ba  (None, 12, 12, 256)          1024      ['separable_conv2d_37[0][0]']
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 256)            0         ['batch_normalization_41[0][0]
#  g2D)                                                               ']
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 256)            33024     ['add_12[0][0]']
#
#  add_13 (Add)                (None, 6, 6, 256)            0         ['max_pooling2d_5[0][0]',
#                                                                      'conv2d_9[0][0]']
#
#  activation_42 (Activation)  (None, 6, 6, 256)            0         ['add_13[0][0]']
#
#  separable_conv2d_38 (Separ  (None, 6, 6, 728)            189400    ['activation_42[0][0]']
#  ableConv2D)
#
#  batch_normalization_42 (Ba  (None, 6, 6, 728)            2912      ['separable_conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 6, 6, 728)            0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  separable_conv2d_39 (Separ  (None, 6, 6, 728)            537264    ['activation_43[0][0]']
#  ableConv2D)
#
#  batch_normalization_43 (Ba  (None, 6, 6, 728)            2912      ['separable_conv2d_39[0][0]']
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 3, 3, 728)            0         ['batch_normalization_43[0][0]
#  g2D)                                                               ']
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 728)            187096    ['add_13[0][0]']
#
#  add_14 (Add)                (None, 3, 3, 728)            0         ['max_pooling2d_6[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  activation_44 (Activation)  (None, 3, 3, 728)            0         ['add_14[0][0]']
#
#  separable_conv2d_40 (Separ  (None, 3, 3, 728)            537264    ['activation_44[0][0]']
#  ableConv2D)
#
#  batch_normalization_44 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  separable_conv2d_41 (Separ  (None, 3, 3, 728)            537264    ['activation_45[0][0]']
#  ableConv2D)
#
#  batch_normalization_45 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  separable_conv2d_42 (Separ  (None, 3, 3, 728)            537264    ['activation_46[0][0]']
#  ableConv2D)
#
#  batch_normalization_46 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_42[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'add_14[0][0]']
#
#  activation_47 (Activation)  (None, 3, 3, 728)            0         ['add_15[0][0]']
#
#  separable_conv2d_43 (Separ  (None, 3, 3, 728)            537264    ['activation_47[0][0]']
#  ableConv2D)
#
#  batch_normalization_47 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  separable_conv2d_44 (Separ  (None, 3, 3, 728)            537264    ['activation_48[0][0]']
#  ableConv2D)
#
#  batch_normalization_48 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  separable_conv2d_45 (Separ  (None, 3, 3, 728)            537264    ['activation_49[0][0]']
#  ableConv2D)
#
#  batch_normalization_49 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_45[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_49[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  activation_50 (Activation)  (None, 3, 3, 728)            0         ['add_16[0][0]']
#
#  separable_conv2d_46 (Separ  (None, 3, 3, 728)            537264    ['activation_50[0][0]']
#  ableConv2D)
#
#  batch_normalization_50 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  separable_conv2d_47 (Separ  (None, 3, 3, 728)            537264    ['activation_51[0][0]']
#  ableConv2D)
#
#  batch_normalization_51 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  separable_conv2d_48 (Separ  (None, 3, 3, 728)            537264    ['activation_52[0][0]']
#  ableConv2D)
#
#  batch_normalization_52 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_48[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_52[0][0]
#                                                                     ',
#                                                                      'add_16[0][0]']
#
#  activation_53 (Activation)  (None, 3, 3, 728)            0         ['add_17[0][0]']
#
#  separable_conv2d_49 (Separ  (None, 3, 3, 728)            537264    ['activation_53[0][0]']
#  ableConv2D)
#
#  batch_normalization_53 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  separable_conv2d_50 (Separ  (None, 3, 3, 728)            537264    ['activation_54[0][0]']
#  ableConv2D)
#
#  batch_normalization_54 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  separable_conv2d_51 (Separ  (None, 3, 3, 728)            537264    ['activation_55[0][0]']
#  ableConv2D)
#
#  batch_normalization_55 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_51[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_55[0][0]
#                                                                     ',
#                                                                      'add_17[0][0]']
#
#  activation_56 (Activation)  (None, 3, 3, 728)            0         ['add_18[0][0]']
#
#  separable_conv2d_52 (Separ  (None, 3, 3, 728)            537264    ['activation_56[0][0]']
#  ableConv2D)
#
#  batch_normalization_56 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  separable_conv2d_53 (Separ  (None, 3, 3, 728)            537264    ['activation_57[0][0]']
#  ableConv2D)
#
#  batch_normalization_57 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  separable_conv2d_54 (Separ  (None, 3, 3, 728)            537264    ['activation_58[0][0]']
#  ableConv2D)
#
#  batch_normalization_58 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_54[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_58[0][0]
#                                                                     ',
#                                                                      'add_18[0][0]']
#
#  activation_59 (Activation)  (None, 3, 3, 728)            0         ['add_19[0][0]']
#
#  separable_conv2d_55 (Separ  (None, 3, 3, 728)            537264    ['activation_59[0][0]']
#  ableConv2D)
#
#  batch_normalization_59 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  separable_conv2d_56 (Separ  (None, 3, 3, 728)            537264    ['activation_60[0][0]']
#  ableConv2D)
#
#  batch_normalization_60 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  separable_conv2d_57 (Separ  (None, 3, 3, 728)            537264    ['activation_61[0][0]']
#  ableConv2D)
#
#  batch_normalization_61 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_57[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_61[0][0]
#                                                                     ',
#                                                                      'add_19[0][0]']
#
#  activation_62 (Activation)  (None, 3, 3, 728)            0         ['add_20[0][0]']
#
#  separable_conv2d_58 (Separ  (None, 3, 3, 728)            537264    ['activation_62[0][0]']
#  ableConv2D)
#
#  batch_normalization_62 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  separable_conv2d_59 (Separ  (None, 3, 3, 728)            537264    ['activation_63[0][0]']
#  ableConv2D)
#
#  batch_normalization_63 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  separable_conv2d_60 (Separ  (None, 3, 3, 728)            537264    ['activation_64[0][0]']
#  ableConv2D)
#
#  batch_normalization_64 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_60[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_64[0][0]
#                                                                     ',
#                                                                      'add_20[0][0]']
#
#  activation_65 (Activation)  (None, 3, 3, 728)            0         ['add_21[0][0]']
#
#  separable_conv2d_61 (Separ  (None, 3, 3, 728)            537264    ['activation_65[0][0]']
#  ableConv2D)
#
#  batch_normalization_65 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_66 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  separable_conv2d_62 (Separ  (None, 3, 3, 728)            537264    ['activation_66[0][0]']
#  ableConv2D)
#
#  batch_normalization_66 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  separable_conv2d_63 (Separ  (None, 3, 3, 728)            537264    ['activation_67[0][0]']
#  ableConv2D)
#
#  batch_normalization_67 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_63[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 3, 3, 728)            0         ['batch_normalization_67[0][0]
#                                                                     ',
#                                                                      'add_21[0][0]']
#
#  activation_68 (Activation)  (None, 3, 3, 728)            0         ['add_22[0][0]']
#
#  separable_conv2d_64 (Separ  (None, 3, 3, 728)            537264    ['activation_68[0][0]']
#  ableConv2D)
#
#  batch_normalization_68 (Ba  (None, 3, 3, 728)            2912      ['separable_conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_69 (Activation)  (None, 3, 3, 728)            0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  separable_conv2d_65 (Separ  (None, 3, 3, 1024)           753048    ['activation_69[0][0]']
#  ableConv2D)
#
#  batch_normalization_69 (Ba  (None, 3, 3, 1024)           4096      ['separable_conv2d_65[0][0]']
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 1024)           0         ['batch_normalization_69[0][0]
#  g2D)                                                               ']
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 1024)           746496    ['add_22[0][0]']
#
#  add_23 (Add)                (None, 2, 2, 1024)           0         ['max_pooling2d_7[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_70 (Activation)  (None, 2, 2, 1024)           0         ['add_23[0][0]']
#
#  separable_conv2d_66 (Separ  (None, 2, 2, 728)            755416    ['activation_70[0][0]']
#  ableConv2D)
#
#  batch_normalization_70 (Ba  (None, 2, 2, 728)            2912      ['separable_conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 2, 2, 728)            0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  separable_conv2d_67 (Separ  (None, 2, 2, 1024)           753048    ['activation_71[0][0]']
#  ableConv2D)
#
#  batch_normalization_71 (Ba  (None, 2, 2, 1024)           4096      ['separable_conv2d_67[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_71[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  dense_1 (Dense)             (None, 7)                    7175      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 17644447 (67.31 MB)
# Trainable params: 17597855 (67.13 MB)
# Non-trainable params: 46592 (182.00 KB)
# __________________________________________________________________________________________________

# %%
xception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
 
batch_size = 128
epochs = 150

# %%
train_labels_one_hot = to_categorical(y_train)
test_labels_one_hot = to_categorical(y_test)

# %%
test_labels_one_hot.shape
train_labels_one_hot.shape
# Out:
# (28709, 7)

# %%
datagen = ImageDataGenerator(
        zoom_range=0.2,          # randomly zoom into images
        rotation_range=10,       # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,   # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,    # randomly flip images
        vertical_flip=False)     # randomly flip images

history = xception.fit(
    datagen.flow(X_train, train_labels_one_hot, batch_size=batch_size),
    steps_per_epoch=int(np.ceil(X_train.shape[0] / float(batch_size))),
    epochs = epochs, 
    validation_data=(X_test, test_labels_one_hot)
)
# Out:
# Epoch 1/150
# 225/225 [==============================] - 79s 207ms/step - loss: 1.6358 - accuracy: 0.3539 - val_loss: 1.8548 - val_accuracy: 0.2494
# Epoch 2/150
# 225/225 [==============================] - 44s 194ms/step - loss: 1.4053 - accuracy: 0.4600 - val_loss: 2.0284 - val_accuracy: 0.2494
# Epoch 3/150
# 225/225 [==============================] - 44s 196ms/step - loss: 1.3080 - accuracy: 0.5008 - val_loss: 1.7644 - val_accuracy: 0.3962
# Epoch 4/150
# 225/225 [==============================] - 44s 195ms/step - loss: 1.2366 - accuracy: 0.5327 - val_loss: 3.8930 - val_accuracy: 0.1858
# Epoch 5/150
# 225/225 [==============================] - 44s 196ms/step - loss: 1.1960 - accuracy: 0.5501 - val_loss: 2.1186 - val_accuracy: 0.3817
# Epoch 6/150
# 225/225 [==============================] - 44s 195ms/step - loss: 1
150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2828 - accuracy: 0.8979 - val_loss: 1.4540 - val_accuracy: 0.6495
# Epoch 96/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2797 - accuracy: 0.8970 - val_loss: 1.5813 - val_accuracy: 0.6559
# Epoch 97/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2729 - accuracy: 0.9024 - val_loss: 1.5419 - val_accuracy: 0.6556
# Epoch 98/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2721 - accuracy: 0.9003 - val_loss: 1.8658 - val_accuracy: 0.6108
# Epoch 99/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2674 - accuracy: 0.9013 - val_loss: 1.6161 - val_accuracy: 0.6386
# Epoch 100/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2642 - accuracy: 0.9055 - val_loss: 1.7838 - val_accuracy: 0.6344
# Epoch 101/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2601 - accuracy: 0.9049 - val_loss: 1.7070 - val_accuracy: 0.6278
# Epoch 102/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2587 - accuracy: 0.9058 - val_loss: 1.7061 - val_accuracy: 0.6408
# Epoch 103/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2458 - accuracy: 0.9106 - val_loss: 1.7666 - val_accuracy: 0.6450
# Epoch 104/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2515 - accuracy: 0.9102 - val_loss: 1.5408 - val_accuracy: 0.6539
# Epoch 105/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2419 - accuracy: 0.9126 - val_loss: 1.5709 - val_accuracy: 0.6286
# Epoch 106/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2432 - accuracy: 0.9127 - val_loss: 2.0062 - val_accuracy: 0.6130
# Epoch 107/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2401 - accuracy: 0.9141 - val_loss: 1.6678 - val_accuracy: 0.6556
# Epoch 108/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2345 - accuracy: 0.9166 - val_loss: 1.5549 - val_accuracy: 0.6623
# Epoch 109/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2249 - accuracy: 0.9193 - val_loss: 1.6278 - val_accuracy: 0.6517
# Epoch 110/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2276 - accuracy: 0.9178 - val_loss: 1.5944 - val_accuracy: 0.6470
# Epoch 111/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2260 - accuracy: 0.9202 - val_loss: 1.5439 - val_accuracy: 0.6581
# Epoch 112/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2278 - accuracy: 0.9163 - val_loss: 1.8002 - val_accuracy: 0.6347
# Epoch 113/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2251 - accuracy: 0.9191 - val_loss: 1.6228 - val_accuracy: 0.6389
# Epoch 114/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2213 - accuracy: 0.9233 - val_loss: 1.6756 - val_accuracy: 0.6403
# Epoch 115/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2150 - accuracy: 0.9245 - val_loss: 1.7096 - val_accuracy: 0.6392
# Epoch 116/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2164 - accuracy: 0.9214 - val_loss: 1.7330 - val_accuracy: 0.6294
# Epoch 117/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2165 - accuracy: 0.9231 - val_loss: 1.5861 - val_accuracy: 0.6573
# Epoch 118/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2082 - accuracy: 0.9267 - val_loss: 1.5425 - val_accuracy: 0.6590
# Epoch 119/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2077 - accuracy: 0.9264 - val_loss: 1.6919 - val_accuracy: 0.6408
# Epoch 120/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2016 - accuracy: 0.9285 - val_loss: 1.9928 - val_accuracy: 0.6094
# Epoch 121/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2107 - accuracy: 0.9236 - val_loss: 1.6166 - val_accuracy: 0.6517
# Epoch 122/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2032 - accuracy: 0.9276 - val_loss: 1.6008 - val_accuracy: 0.6581
# Epoch 123/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1983 - accuracy: 0.9297 - val_loss: 1.6278 - val_accuracy: 0.6587
# Epoch 124/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1950 - accuracy: 0.9328 - val_loss: 1.6469 - val_accuracy: 0.6617
# Epoch 125/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1946 - accuracy: 0.9301 - val_loss: 1.6801 - val_accuracy: 0.6467
# Epoch 126/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.2009 - accuracy: 0.9287 - val_loss: 1.6085 - val_accuracy: 0.6637
# Epoch 127/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1936 - accuracy: 0.9317 - val_loss: 1.7230 - val_accuracy: 0.6400
# Epoch 128/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1903 - accuracy: 0.9332 - val_loss: 1.6308 - val_accuracy: 0.6523
# Epoch 129/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1892 - accuracy: 0.9334 - val_loss: 1.7858 - val_accuracy: 0.6509
# Epoch 130/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1862 - accuracy: 0.9339 - val_loss: 1.6340 - val_accuracy: 0.6601
# Epoch 131/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1904 - accuracy: 0.9317 - val_loss: 1.6764 - val_accuracy: 0.6303
# Epoch 132/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1770 - accuracy: 0.9382 - val_loss: 1.8112 - val_accuracy: 0.6227
# Epoch 133/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1819 - accuracy: 0.9347 - val_loss: 1.7737 - val_accuracy: 0.6431
# Epoch 134/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1832 - accuracy: 0.9361 - val_loss: 1.6402 - val_accuracy: 0.6709
# Epoch 135/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1773 - accuracy: 0.9388 - val_loss: 1.6859 - val_accuracy: 0.6470
# Epoch 136/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1774 - accuracy: 0.9350 - val_loss: 1.9141 - val_accuracy: 0.6199
# Epoch 137/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1752 - accuracy: 0.9368 - val_loss: 1.7156 - val_accuracy: 0.6570
# Epoch 138/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1791 - accuracy: 0.9366 - val_loss: 1.6982 - val_accuracy: 0.6369
# Epoch 139/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1724 - accuracy: 0.9393 - val_loss: 1.8102 - val_accuracy: 0.6241
# Epoch 140/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1711 - accuracy: 0.9402 - val_loss: 1.6344 - val_accuracy: 0.6712
# Epoch 141/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1759 - accuracy: 0.9390 - val_loss: 1.7328 - val_accuracy: 0.6367
# Epoch 142/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1679 - accuracy: 0.9403 - val_loss: 1.6787 - val_accuracy: 0.6592
# Epoch 143/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1700 - accuracy: 0.9395 - val_loss: 1.7294 - val_accuracy: 0.6422
# Epoch 144/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1665 - accuracy: 0.9422 - val_loss: 1.7657 - val_accuracy: 0.6442
# Epoch 145/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1627 - accuracy: 0.9418 - val_loss: 1.6705 - val_accuracy: 0.6617
# Epoch 146/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1611 - accuracy: 0.9414 - val_loss: 1.8415 - val_accuracy: 0.6403
# Epoch 147/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1637 - accuracy: 0.9420 - val_loss: 1.7604 - val_accuracy: 0.6336
# Epoch 148/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1574 - accuracy: 0.9447 - val_loss: 1.7138 - val_accuracy: 0.6397
# Epoch 149/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1584 - accuracy: 0.9439 - val_loss: 1.6584 - val_accuracy: 0.6592
# Epoch 150/150
# 225/225 [==============================] - 44s 195ms/step - loss: 0.1614 - accuracy: 0.9421 - val_loss: 1.6632 - val_accuracy: 0.6431

# %%
#Plotting accuracy and loss curves for Xception Model

# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=2.0)
plt.plot(history.history['val_loss'],'b',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# # Save the model

# %%
save_path = '/kaggle/working/'
#save the model weights
json_string = xception.to_json()
xception.save_weights('model_xception.h5')
xception.save(save_path+'model_xception.keras')
open(save_path + 'model_xception.json', 'w').write(json_string)
xception.save(save_path + 'Emotion_Face_Detection_Model_Xception.keras')
